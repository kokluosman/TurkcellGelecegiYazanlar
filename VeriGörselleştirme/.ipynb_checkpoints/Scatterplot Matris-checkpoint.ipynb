# %%
import seaborn as sns
iris = sns.load_dataset("iris")
df = iris.copyy()
df.head()
#Species = tür
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Hikayesi Çicek türleri var. Yaprakları genişliği vs

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
sns.pairplot(df);

# %%
#Bu Görselde (Saçılım grafiği) yapısal form yoksa ynai toz bulutu şeklindeyse o iki değişken arasında bir ilişki olmadığını
#söyler.
#Oluşturulan scatterplot içerisinde gözlem noktaları incelendiğinde birbirinden farklı köşelerde kümeleniyorsa
#çarprazlama durumundan kaynaklı olan, farklı farklı kümelenmeleri ifade eden bazı alt gruplar vardır.

# %%
sns.pairplot(df,hue="species");
# Out:
# C:\Users\koklu\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df,hue="species",markers=["o","s","D"]);
# Out:
# C:\Users\koklu\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(df,kind ="reg");# Doğru ekleme

# %%
sns.pairplot(df,kind ="reg",hue="species");# Doğru ekleme
# Out:
# C:\Users\koklu\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
